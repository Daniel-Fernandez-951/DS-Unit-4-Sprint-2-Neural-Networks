# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # Train Practice
#
# ## *Data Science Unit 4 Sprint 2 Assignment 4*
#
# Continue to use TensorFlow Keras & a sample of the [Quickdraw dataset](https://github.com/googlecreativelab/quickdraw-dataset) to build a sketch classification model. The dataset has been sampled to only 10 classes and 10000 observations per class. Apply regularization techniques to your model.
#
# *Don't forgot to switch to GPU on Colab!*

# %% [markdown]
# ## Regularization
#
# Using your best performing model from the previous module, apply each of the following regularization strategies:
# * Early Stopping
# * Dropout
# * Weight Decay
# * Weight Constraint

# %%
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, Ftrl, Nadam
from sklearn.model_selection import train_test_split
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras import Sequential
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import datetime
import os

# %reload_ext tensorboard

# %%
data = np.load('../quickdraw10.npz')
data.files
    
def load_quickdraw10(path, x_loc, y_loc, outlier_val=-1):
    """
    Get loaded data and split; returns X_train/test and y train_test
    with 40% split.
    Normalize data; enter in outlier value or keep default (-1) to 
    select auto and find X max.
    
    Input: data path, X and y index label
    
    :Return: X_train, X_test, y_train, y_test
    """
    X = path[x_loc]
    y = path[y_loc]
    X_train, X_test, y_train, y_test = train_test_split(X, 
                                                        y, 
                                                        test_size = 0.4,
                                                        random_state=445642)
    # Read or find outlier, -1 is auto, else inputed value used.
    if outlier_val == -1:
        outlier_val = X.max()
    else:
        outlier_val = outlier_val
    
    # Normalize X_test/train by outlier value
    X_train, X_test = X_train.astype('float32') / outlier_val, X_test.astype('float32') / outlier_val
    
    # Print info
    print(f'X shape = {X.shape}\n'
          f'y shape = {y.shape}\n'
          f'X (max, min) = ({X.max()}, {X.min()})\n'
          f'X (train.shape, test.shape) = [ {X_train.shape}, {X_test.shape} ]\n\n'
          f'y Unique = {len(np.unique(y))}')
    
    return X_train, y_train, X_test, y_test

# Set test and train sets
X_train, y_train, X_test, y_test = load_quickdraw10(path=data,
                                                   x_loc='arr_0',
                                                   y_loc='arr_1')
# Out:
# X shape = (100000, 784)
# y shape = (100000,)
# X (max, min) = (255, 0)
# X (train.shape, test.shape) = [ (60000, 784), (40000, 784) ]
#
# y Unique = 10

# %%
# 1) Create 2 dir for logging files 
# create 2 dir -- one for tensorboard results and one for early stopping
logdir = os.path.join("logs", 
                      "EarlyStopping+WeightConstraint+Dropout")

# 2) Instantiate the callbacks 
# instantiate a tensorboard callback object
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)

# instantiate a early stopping clallback object 
# docs: https://keras.io/api/callbacks/early_stopping/
stop = EarlyStopping(monitor="val_loss", # track the progress of the test loss 
                     min_delta=0.001, # define threshold for what constitutes an improvment 
                     patience=5) # if an improvement doesn't happen after 3 epoches, stop training

# %%
def create_model(X_train, X_test, y_train, 
                 y_test, hparams, opt=None, 
                 epochs=10, p_dropout=0.2):
    """
    SGD, Adam, Adadelta, Ftrl, nadam or hparams
    """
    if opt == None:
        opt = hparams[HP_OPTIMIZER]
    elif opt.lower() == 'sgd':
        opt = SGD(learning_rate=hparams[HP_LEARNING_RATE])
    elif opt.lower() == 'adam':
        opt = Adam(learning_rate=hparams[HP_LEARNING_RATE])
    elif opt.lower() == 'adadelta':
        opt = Adadelta(learning_rate=hparams[HP_LEARNING_RATE])
    elif opt.lower() == 'ftrl':
        opt = Ftrl(learning_rate=hparams[HP_LEARNING_RATE])
    elif opt.lower() == 'nadam':
        opt = Nadam(learning_rate=hparams[HP_LEARNING_RATE])
    else:
        raise ValueError(f"Unknown optimizer input of {opt} used")
    
    # Instanciate weight constraint
    wc = MaxNorm(max_value=2)
    
    # Model Creation
    model = tf.keras.Sequential([
        Flatten(),
        # Layer 1
        Dense(hparams[HP_NUM_UNITS], kernel_constraint=wc),
        ReLU(negative_slope=0.01),
        Dropout(p_dropout),
        # Layer 2
        Dense(64, kernel_constraint=wc),
        ReLU(negative_slope=0.1),
        Dropout(p_dropout),
        # Layer 3 
        Dense(32, kernel_constraint=wc),
        ReLU(negative_slope=0.01),
        Dropout(p_dropout),
        # Output Layer
        Dense(10, activation='softmax')
    ])
    
    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    model.fit(X_train, y_train, 
              epochs=epochs,
              validation_data=(X_test, y_test),
              callbacks=[tensorboard_callback, stop])
        

    _, accuracy = model.evaluate(X_test, y_test)
    
    return accuracy

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([16,32,100,200,300]))
HP_LEARNING_RATE = hp.HParam('learning_rate', hp.RealInterval(0.001,0.1))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
METRIC_ACCURACY = 'accuracy'
GRID_SEARCH_RESULTS_DIR = 'logs/hparam_tuning'
# creating a dir to save/log our gridsearch results for use with tensorboard 
with tf.summary.create_file_writer(GRID_SEARCH_RESULTS_DIR).as_default():
    hp.hparams_config(
        # store h-params and their values 
        hparams=[HP_NUM_UNITS, HP_LEARNING_RATE, HP_OPTIMIZER],
        # store metrics to score the model 
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')])

# %%
def run(run_dir, hparams):

    with tf.summary.create_file_writer(run_dir).as_default():
        # record the values used in this trial
        hp.hparams(hparams)  

        # call create_model to build, train, and score model on parameter values 
        accuracy = create_model(
                                hparams=hparams, 
                                X_train=X_train, X_test=X_test,
                                y_train=y_train, y_test=y_test,
                                opt=None, epochs=20
                               )

        # store trained accuracy to file 
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)
        
session_num = 0 

for num_units in HP_NUM_UNITS.domain.values:
    for learning_rate in (HP_LEARNING_RATE.domain.min_value, HP_LEARNING_RATE.domain.max_value):
        for optimizer in HP_OPTIMIZER.domain.values:

            # as we loop through all the hyper-param values
            # the store each unique combination in the dictionary hparams
            hparams = {
               HP_NUM_UNITS: num_units,
               HP_LEARNING_RATE: learning_rate,
               HP_OPTIMIZER: optimizer
            }

            run_name = f"run-{session_num}"
            print(f"--- Starting trial: {run_name}")
            print({h.name: hparams[h] for h in hparams})

            # exectue the run function, which runs the training of the models 
            run('logs/hparam_tuning/' + run_name, hparams)
            session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 16, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.4560 - accuracy: 0.4939 - val_loss: 0.8317 - val_accuracy: 0.7460
# Epoch 2/20
# 1875/1875 [==============================] - 2s 987us/step - loss: 0.9845 - accuracy: 0.6820 - val_loss: 0.7609 - val_accuracy: 0.7663
# Epoch 3/20
# 1875/1875 [==============================] - 2s 982us/step - loss: 0.9289 - accuracy: 0.7023 - val_loss: 0.7565 - val_accuracy: 0.7712
# Epoch 4/20
# 1875/1875 [==============================] - 2s 997us/step - loss: 0.8974 - accuracy: 0.7154 - val_loss: 0.7264 - val_accuracy: 0.7821
# Epoch 5/20
# 1875/1875 [==============================] - 2s 973us/step - loss: 0.8816 - accuracy: 0.7192 - val_loss: 0.7128 - val_accuracy: 0.7837
# Epoch 6/20
# 1875/1875 [==============================] - 2s 970us/step - loss: 0.8660 - accuracy: 0.7270 - val_loss: 0.6925 - val_accuracy: 0.7911
# Epoch 7/20
# 1875/1875 [==============================] - 2s 973us/step - loss: 0.8496 - accuracy: 0.7317 - val_loss: 0.6906 - val_accuracy: 0.7928
# Epoch 8/20
# 1875/1875 [==============================] - 2s 971us/step - loss: 0.8420 - accuracy: 0.7360 - val_loss: 0.6864 - val_accuracy: 0.7930
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8365 - accuracy: 0.7397 - val_loss: 0.6878 - val_accuracy: 0.7895
# Epoch 10/20
# 1875/1875 [==============================] - 2s 987us/step - loss: 0.8298 - accuracy: 0.7427 - val_loss: 0.6777 - val_accuracy: 0.7929
# Epoch 11/20
# 1875/1875 [==============================] - 2s 979us/step - loss: 0.8252 - accuracy: 0.7439 - val_loss: 0.6712 - val_accuracy: 0.7967
# Epoch 12/20
# 1875/1875 [==============================] - 2s 996us/step - loss: 0.8172 - accuracy: 0.7443 - val_loss: 0.6680 - val_accuracy: 0.7973
# Epoch 13/20
# 1875/1875 [==============================] - 2s 972us/step - loss: 0.8207 - accuracy: 0.7456 - val_loss: 0.6802 - val_accuracy: 0.7908
# Epoch 14/20
# 1875/1875 [==============================] - 2s 973us/step - loss: 0.8193 - accuracy: 0.7462 - val_loss: 0.6618 - val_accuracy: 0.8015
# Epoch 15/20
# 1875/1875 [==============================] - 2s 985us/step - loss: 0.8207 - accuracy: 0.7449 - val_loss: 0.6578 - val_accuracy: 0.8002
# Epoch 16/20
# 1875/1875 [==============================] - 2s 999us/step - loss: 0.8096 - accuracy: 0.7491 - val_loss: 0.6648 - val_accuracy: 0.7982
20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4766 - accuracy: 0.8577 - val_loss: 0.4613 - val_accuracy: 0.8625
# 1250/1250 [==============================] - 1s 493us/step - loss: 0.4613 - accuracy: 0.8625
# --- Starting trial: run-9
# {'num_units': 100, 'learning_rate': 0.001, 'optimizer': 'sgd'}
# Epoch 1/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.8373 - accuracy: 0.3508 - val_loss: 0.9881 - val_accuracy: 0.6926
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.1095 - accuracy: 0.6445 - val_loss: 0.8139 - val_accuracy: 0.7537
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.9519 - accuracy: 0.7019 - val_loss: 0.7351 - val_accuracy: 0.7791
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8632 - accuracy: 0.7351 - val_loss: 0.6856 - val_accuracy: 0.7929
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8007 - accuracy: 0.7544 - val_loss: 0.6459 - val_accuracy: 0.8066
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7519 - accuracy: 0.7723 - val_loss: 0.6177 - val_accuracy: 0.8154
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7257 - accuracy: 0.7821 - val_loss: 0.5978 - val_accuracy: 0.8212
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6960 - accuracy: 0.7939 - val_loss: 0.5805 - val_accuracy: 0.8266
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6631 - accuracy: 0.8038 - val_loss: 0.5684 - val_accuracy: 0.8311
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6444 - accuracy: 0.8088 - val_loss: 0.5560 - val_accuracy: 0.8340
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6330 - accuracy: 0.8117 - val_loss: 0.5522 - val_accuracy: 0.8354
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6133 - accuracy: 0.8174 - val_loss: 0.5372 - val_accuracy: 0.8391
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5939 - accuracy: 0.8243 - val_loss: 0.5308 - val_accuracy: 0.8413
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5892 - accuracy: 0.8261 - val_loss: 0.5300 - val_accuracy: 0.8425
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5726 - accuracy: 0.8304 - val_loss: 0.5187 - val_accuracy: 0.8461
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5547 - accuracy: 0.8350 - val_loss: 0.5109 - val_accuracy: 0.8480
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5537 - accuracy: 0.8352 - val_loss: 0.5132 - val_accuracy: 0.8473
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5446 - accuracy: 0.8377 - val_loss: 0.5015 - val_accuracy: 0.8510
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5423 - accuracy: 0.8387 - val_loss: 0.4974 - val_accuracy: 0.8512
# Epoch 20/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5237 - accuracy: 0.8450 - val_loss: 0.4958 - val_accuracy: 0.8534
# 1250/1250 [==============================] - 1s 506us/step - loss: 0.4958 - accuracy: 0.8534
# --- Starting trial: run-10
# {'num_units': 100, 'learning_rate': 0.1, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.2003 - accuracy: 0.6057 - val_loss: 0.6119 - val_accuracy: 0.8118
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6865 - accuracy: 0.7928 - val_loss: 0.5500 - val_accuracy: 0.8328
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6110 - accuracy: 0.8188 - val_loss: 0.5298 - val_accuracy: 0.8403
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5779 - accuracy: 0.8282 - val_loss: 0.5084 - val_accuracy: 0.8462
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5508 - accuracy: 0.8348 - val_loss: 0.5138 - val_accuracy: 0.8462
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0
20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5845 - accuracy: 0.8253 - val_loss: 0.5173 - val_accuracy: 0.8440
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5699 - accuracy: 0.8301 - val_loss: 0.5118 - val_accuracy: 0.8449
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5589 - accuracy: 0.8337 - val_loss: 0.5068 - val_accuracy: 0.8469
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5503 - accuracy: 0.8368 - val_loss: 0.5007 - val_accuracy: 0.8480
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5460 - accuracy: 0.8390 - val_loss: 0.4981 - val_accuracy: 0.8493
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5289 - accuracy: 0.8401 - val_loss: 0.4909 - val_accuracy: 0.8522
# Epoch 20/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5217 - accuracy: 0.8446 - val_loss: 0.4897 - val_accuracy: 0.8512
# 1250/1250 [==============================] - 1s 503us/step - loss: 0.4897 - accuracy: 0.8512
# --- Starting trial: run-12
# {'num_units': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.1306 - accuracy: 0.6356 - val_loss: 0.5722 - val_accuracy: 0.8278
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6305 - accuracy: 0.8113 - val_loss: 0.5149 - val_accuracy: 0.8462
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5681 - accuracy: 0.8330 - val_loss: 0.5132 - val_accuracy: 0.8458
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5166 - accuracy: 0.8474 - val_loss: 0.4910 - val_accuracy: 0.8524
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4871 - accuracy: 0.8547 - val_loss: 0.4739 - val_accuracy: 0.8571
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4746 - accuracy: 0.8593 - val_loss: 0.4659 - val_accuracy: 0.8586
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4562 - accuracy: 0.8649 - val_loss: 0.4553 - val_accuracy: 0.8640
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4573 - accuracy: 0.8642 - val_loss: 0.4789 - val_accuracy: 0.8598
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4496 - accuracy: 0.8657 - val_loss: 0.4614 - val_accuracy: 0.8625
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4343 - accuracy: 0.8712 - val_loss: 0.4501 - val_accuracy: 0.8642
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4257 - accuracy: 0.8743 - val_loss: 0.4547 - val_accuracy: 0.8621
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4254 - accuracy: 0.8733 - val_loss: 0.4581 - val_accuracy: 0.8593
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4112 - accuracy: 0.8771 - val_loss: 0.4513 - val_accuracy: 0.8644
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4200 - accuracy: 0.8735 - val_loss: 0.4549 - val_accuracy: 0.8630
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4179 - accuracy: 0.8761 - val_loss: 0.4578 - val_accuracy: 0.8600
# 1250/1250 [==============================] - 1s 496us/step - loss: 0.4578 - accuracy: 0.8600
# --- Starting trial: run-13
# {'num_units': 200, 'learning_rate': 0.001, 'optimizer': 'sgd'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.7370 - accuracy: 0.3881 - val_loss: 0.9114 - val_accuracy: 0.7282
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0372 - accuracy: 0.6727 - val_loss: 0.7626 - val_accuracy: 0.7736
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8859 - accuracy: 0.7274 - val_loss: 0.6867 - val_accuracy: 0.7934
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7971 - accuracy: 0.7599 - val_loss: 0.6416 - val_accuracy: 0.8080
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7468 - accuracy: 0.7764 - val_loss: 0.6032 - val_accuracy: 0.8182
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6970 - accuracy: 0.7903 - val_loss: 0.5780 - val_accuracy: 0.8258
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6668 - accuracy: 0.8002 - val_loss: 0.5574 - val_accuracy: 0.8324
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6369 - accuracy: 0.8113 - val_loss: 0.5429 - val_accuracy: 0.8359
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6067 - accuracy: 0.8187 - val_loss: 0.5320 - val_accuracy: 0.8389
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5832 - accuracy: 0.8254 - val_loss: 0.5176 - val_accuracy: 0.8428
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5682 - accuracy: 0.8328 - val_loss: 0.5085 - val_accuracy: 0.8457
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5554 - accuracy: 0.8328 - val_loss: 0.4999 - val_accuracy: 0.8477
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5367 - accuracy: 0.8405 - val_loss: 0.4906 - val_accuracy: 0.8511
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5176 - accuracy: 0.8472 - val_loss: 0.4864 - val_accuracy: 0.8518
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5153 - accuracy: 0.8472 - val_loss: 0.4826 - val_accuracy: 0.8530
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4982 - accuracy: 0.8512 - val_loss: 0.4769 - val_accuracy: 0.8548
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4824 - accuracy: 0.8566 - val_loss: 0.4709 - val_accuracy: 0.8583
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4730 - accuracy: 0.8587 - val_loss: 0.4709 - val_accuracy: 0.8580
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4650 - accuracy: 0.8628 - val_loss: 0.4615 - val_accuracy: 0.8605
# Epoch 20/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4628 - accuracy: 0.8613 - val_loss: 0.4593 - val_accuracy: 0.8611
# 1250/1250 [==============================] - 1s 498us/step - loss: 0.4593 - accuracy: 0.8611
# --- Starting trial: run-14
# {'num_units': 200, 'learning_rate': 0.1, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.1072 - accuracy: 0.6422 - val_loss: 0.5732 - val_accuracy: 0.8257
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6328 - accuracy: 0.8117 - val_loss: 0.5237 - val_accuracy: 0.8417
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5562 - accuracy: 0.8368 - val_loss: 0.5013 - val_accuracy: 0.8488
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5117 - accuracy: 0.8491 - val_loss: 0.4800 - val_accuracy: 0.8560
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4865 - accuracy: 0.8548 - val_loss: 0.4796 - val_accuracy: 0.8548
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4672 - accuracy: 0.8622 - val_loss: 0.4685 - val_accuracy: 0.8577
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4554 - accuracy: 0.8643 - val_loss: 0.4582 - val_accuracy: 0.8632
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4473 - accuracy: 0.8682 - val_loss: 0.4762 - val_accuracy: 0.8557
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4388 - accuracy: 0.8703 - val_loss: 0.4458 - val_accuracy: 0.8667
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4304 - accuracy: 0.8700 - val_loss: 0.4544 - val_accuracy: 0.8666
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4188 - accuracy: 0.8760 - val_loss: 0.4467 - val_accuracy: 0.8669
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4223 - accuracy: 0.8748 - val_loss: 0.4501 - val_accuracy: 0.8637
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4152 - accuracy: 0.8757 - val_loss: 0.4466 - val_accuracy: 0.8667
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4038 - accuracy: 0.8805 - val_loss: 0.4610 - val_accuracy: 0.8617
# 1250/1250 [==============================] - 1s 495us/step - loss: 0.4610 - accuracy: 0.8617
# --- Starting trial: run-15
# {'num_units': 200, 'learning_rate': 0.1, 'optimizer': 'sgd'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.8164 - accuracy: 0.3587 - val_loss: 0.9531 - val_accuracy: 0.7082
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0623 - accuracy: 0.6578 - val_loss: 0.7864 - val_accuracy: 0.7644
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.9098 - accuracy: 0.7185 - val_loss: 0.7117 - val_accuracy: 0.7854
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8175 - accuracy: 0.7529 - val_loss: 0.6526 - val_accuracy: 0.8033
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7588 - accuracy: 0.7690 - val_loss: 0.6158 - val_accuracy: 0.8159
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7008 - accuracy: 0.7880 - val_loss: 0.5891 - val_accuracy: 0.8235
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6763 - accuracy: 0.7958 - val_loss: 0.5649 - val_accuracy: 0.8306
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6446 - accuracy: 0.8088 - val_loss: 0.5463 - val_accuracy: 0.8372
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6237 - accuracy: 0.8127 - val_loss: 0.5329 - val_accuracy: 0.8399
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5885 - accuracy: 0.8253 - val_loss: 0.5224 - val_accuracy: 0.8444
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5765 - accuracy: 0.8280 - val_loss: 0.5116 - val_accuracy: 0.8463
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5597 - accuracy: 0.8348 - val_loss: 0.5025 - val_accuracy: 0.8496
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5475 - accuracy: 0.8375 - val_loss: 0.4968 - val_accuracy: 0.8515
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5254 - accuracy: 0.8440 - val_loss: 0.4890 - val_accuracy: 0.8544
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5117 - accuracy: 0.8476 - val_loss: 0.4843 - val_accuracy: 0.8550
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5004 - accuracy: 0.8525 - val_loss: 0.4796 - val_accuracy: 0.8573
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4850 - accuracy: 0.8566 - val_loss: 0.4711 - val_accuracy: 0.8590
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4758 - accuracy: 0.8582 - val_loss: 0.4696 - val_accuracy: 0.8592
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4651 - accuracy: 0.8611 - val_loss: 0.4686 - val_accuracy: 0.8601
# Epoch 20/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4554 - accuracy: 0.8646 - val_loss: 0.4637 - val_accuracy: 0.8613
# 1250/1250 [==============================] - 1s 512us/step - loss: 0.4637 - accuracy: 0.8613
# --- Starting trial: run-16
# {'num_units': 300, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.0991 - accuracy: 0.6459 - val_loss: 0.5581 - val_accuracy: 0.8326
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6019 - accuracy: 0.8208 - val_loss: 0.5130 - val_accuracy: 0.8434
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5313 - accuracy: 0.8454 - val_loss: 0.4864 - val_accuracy: 0.8528
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4911 - accuracy: 0.8571 - val_loss: 0.4749 - val_accuracy: 0.8597
# Epoch 5/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4556 - accuracy: 0.8652 - val_loss: 0.4575 - val_accuracy: 0.8611
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4379 - accuracy: 0.8712 - val_loss: 0.4542 - val_accuracy: 0.8643
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4241 - accuracy: 0.8730 - val_loss: 0.4554 - val_accuracy: 0.8628
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4160 - accuracy: 0.8759 - val_loss: 0.4421 - val_accuracy: 0.8676
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4076 - accuracy: 0.8795 - val_loss: 0.4376 - val_accuracy: 0.8715
# Epoch 10/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4013 - accuracy: 0.8778 - val_loss: 0.4407 - val_accuracy: 0.8680
# Epoch 11/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3908 - accuracy: 0.8831 - val_loss: 0.4585 - val_accuracy: 0.8676
# Epoch 12/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3845 - accuracy: 0.8854 - val_loss: 0.4609 - val_accuracy: 0.8669
# Epoch 13/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3812 - accuracy: 0.8863 - val_loss: 0.4453 - val_accuracy: 0.8655
# Epoch 14/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3753 - accuracy: 0.8884 - val_loss: 0.4351 - val_accuracy: 0.8704
# Epoch 15/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3756 - accuracy: 0.8888 - val_loss: 0.4383 - val_accuracy: 0.8703
# Epoch 16/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3757 - accuracy: 0.8875 - val_loss: 0.4498 - val_accuracy: 0.8708
# Epoch 17/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3688 - accuracy: 0.8872 - val_loss: 0.4656 - val_accuracy: 0.8565
# Epoch 18/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3693 - accuracy: 0.8886 - val_loss: 0.4392 - val_accuracy: 0.8689
# Epoch 19/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3684 - accuracy: 0.8896 - val_loss: 0.4447 - val_accuracy: 0.8666
# 1250/1250 [==============================] - 1s 541us/step - loss: 0.4447 - accuracy: 0.8666
# --- Starting trial: run-17
# {'num_units': 300, 'learning_rate': 0.001, 'optimizer': 'sgd'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.8270 - accuracy: 0.3545 - val_loss: 0.9436 - val_accuracy: 0.7167
# Epoch 2/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0506 - accuracy: 0.6657 - val_loss: 0.7811 - val_accuracy: 0.7623
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8829 - accuracy: 0.7284 - val_loss: 0.7024 - val_accuracy: 0.7880
# Epoch 4/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8031 - accuracy: 0.7547 - val_loss: 0.6542 - val_accuracy: 0.8033
# Epoch 5/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7521 - accuracy: 0.7722 - val_loss: 0.6165 - val_accuracy: 0.8139
# Epoch 6/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7053 - accuracy: 0.7867 - val_loss: 0.5876 - val_accuracy: 0.8241
# Epoch 7/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6643 - accuracy: 0.8026 - val_loss: 0.5679 - val_accuracy: 0.8284
# Epoch 8/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6345 - accuracy: 0.8086 - val_loss: 0.5445 - val_accuracy: 0.8354
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6018 - accuracy: 0.8189 - val_loss: 0.5326 - val_accuracy: 0.8398
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5803 - accuracy: 0.8278 - val_loss: 0.5149 - val_accuracy: 0.8454
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5608 - accuracy: 0.8333 - val_loss: 0.5061 - val_accuracy: 0.8490
# Epoch 12/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5440 - accuracy: 0.8388 - val_loss: 0.4956 - val_accuracy: 0.8518
# Epoch 13/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5173 - accuracy: 0.8450 - val_loss: 0.4867 - val_accuracy: 0.8533
# Epoch 14/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5065 - accuracy: 0.8479 - val_loss: 0.4763 - val_accuracy: 0.8573
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4932 - accuracy: 0.8542 - val_loss: 0.4705 - val_accuracy: 0.8593
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4716 - accuracy: 0.8584 - val_loss: 0.4652 - val_accuracy: 0.8592
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4569 - accuracy: 0.8658 - val_loss: 0.4586 - val_accuracy: 0.8622
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4527 - accuracy: 0.8669 - val_loss: 0.4567 - val_accuracy: 0.8633
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4451 - accuracy: 0.8693 - val_loss: 0.4538 - val_accuracy: 0.8656
# Epoch 20/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4243 - accuracy: 0.8749 - val_loss: 0.4493 - val_accuracy: 0.8671
# 1250/1250 [==============================] - 1s 533us/step - loss: 0.4493 - accuracy: 0.8671
# --- Starting trial: run-18
# {'num_units': 300, 'learning_rate': 0.1, 'optimizer': 'adam'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.0934 - accuracy: 0.6448 - val_loss: 0.5686 - val_accuracy: 0.8269
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6056 - accuracy: 0.8208 - val_loss: 0.5130 - val_accuracy: 0.8480
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5304 - accuracy: 0.8433 - val_loss: 0.4820 - val_accuracy: 0.8576
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4788 - accuracy: 0.8586 - val_loss: 0.4903 - val_accuracy: 0.8554
# Epoch 5/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4601 - accuracy: 0.8627 - val_loss: 0.4589 - val_accuracy: 0.8630
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4378 - accuracy: 0.8705 - val_loss: 0.4505 - val_accuracy: 0.8672
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4155 - accuracy: 0.8778 - val_loss: 0.4421 - val_accuracy: 0.8682
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4192 - accuracy: 0.8748 - val_loss: 0.4465 - val_accuracy: 0.8672
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4038 - accuracy: 0.8801 - val_loss: 0.4590 - val_accuracy: 0.8614
# Epoch 10/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3879 - accuracy: 0.8844 - val_loss: 0.4469 - val_accuracy: 0.8677
# Epoch 11/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3911 - accuracy: 0.8828 - val_loss: 0.4421 - val_accuracy: 0.8700
# Epoch 12/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3858 - accuracy: 0.8843 - val_loss: 0.4449 - val_accuracy: 0.8689
# 1250/1250 [==============================] - 1s 536us/step - loss: 0.4449 - accuracy: 0.8689
# --- Starting trial: run-19
# {'num_units': 300, 'learning_rate': 0.1, 'optimizer': 'sgd'}
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.8071 - accuracy: 0.3583 - val_loss: 0.9310 - val_accuracy: 0.7167
# Epoch 2/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0415 - accuracy: 0.6735 - val_loss: 0.7691 - val_accuracy: 0.7679
# Epoch 3/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8856 - accuracy: 0.7270 - val_loss: 0.6884 - val_accuracy: 0.7931
# Epoch 4/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7941 - accuracy: 0.7585 - val_loss: 0.6408 - val_accuracy: 0.8072
# Epoch 5/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7336 - accuracy: 0.7806 - val_loss: 0.6011 - val_accuracy: 0.8207
# Epoch 6/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6823 - accuracy: 0.7961 - val_loss: 0.5735 - val_accuracy: 0.8266
# Epoch 7/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6475 - accuracy: 0.8075 - val_loss: 0.5496 - val_accuracy: 0.8338
# Epoch 8/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6118 - accuracy: 0.8147 - val_loss: 0.5304 - val_accuracy: 0.8389
# Epoch 9/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5882 - accuracy: 0.8247 - val_loss: 0.5177 - val_accuracy: 0.8429
# Epoch 10/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5624 - accuracy: 0.8315 - val_loss: 0.5046 - val_accuracy: 0.8463
# Epoch 11/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5454 - accuracy: 0.8364 - val_loss: 0.4947 - val_accuracy: 0.8494
# Epoch 12/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5205 - accuracy: 0.8443 - val_loss: 0.4854 - val_accuracy: 0.8516
# Epoch 13/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5118 - accuracy: 0.8488 - val_loss: 0.4769 - val_accuracy: 0.8543
# Epoch 14/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4911 - accuracy: 0.8548 - val_loss: 0.4688 - val_accuracy: 0.8577
# Epoch 15/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4798 - accuracy: 0.8582 - val_loss: 0.4641 - val_accuracy: 0.8595
# Epoch 16/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4614 - accuracy: 0.8627 - val_loss: 0.4561 - val_accuracy: 0.8609
# Epoch 17/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4428 - accuracy: 0.8691 - val_loss: 0.4522 - val_accuracy: 0.8646
# Epoch 18/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4396 - accuracy: 0.8708 - val_loss: 0.4531 - val_accuracy: 0.8637
# Epoch 19/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4358 - accuracy: 0.8699 - val_loss: 0.4497 - val_accuracy: 0.8652
# Epoch 20/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4144 - accuracy: 0.8770 - val_loss: 0.4404 - val_accuracy: 0.8677
# 1250/1250 [==============================] - 1s 530us/step - loss: 0.4404 - accuracy: 0.8677

# %% [markdown]
# ## Deploy
#
# Save your model's weights using the Checkpoint function. Try reloading the model and making inference on your validation dataset.

# %%
# %tensorboard --logdir=logs/ --host localhost --port 8090
# Out:
# Reusing TensorBoard on port 8090 (pid 29788), started 0:53:12 ago. (Use '!kill 29788' to kill it.)
#       <iframe id="tensorboard-frame-ed25f6ec70bcdbba" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ed25f6ec70bcdbba");
#           const url = new URL("/", window.location);
#           const port = 8090;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Stretch Goals
# - Mount your Google Drive to Colab to persist your model checkpoint files.
# - Research L2 normalization (weight decay)
# - Write a custom callback function to stop training after you reach .88 validation accuracy.
# - Select a new dataset and apply a neural network to it.
# - Research TensorFlow Serving
# - Play [QuickDraw](https://quickdraw.withgoogle.com/data)
# - Create a static webpage using TensorFlow.js to serve a model. Check out [Teachable Machine Learning](https://teachablemachine.withgoogle.com/) for ideas.
